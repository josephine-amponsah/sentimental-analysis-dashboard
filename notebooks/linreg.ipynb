# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt 
import sklearn as sk
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score
from sklearn.preprocessing import StandardScaler

# %%
data = pd.read_csv(r'C:\\Users\\HP\\Downloads\\mybooks\\project\\ads-proj\\ad-sales-ml-proj\\data\\joinedData.csv', index_col = 0)

# %%
data['days'] = 1

# %%
data.head()
# Out:
#     createdAt platformCode  channelCode  marketingInvestment  impressions  \
# 0  2020-01-02      AdWords  adwords_bra               167.09        408.0
# 1  2020-01-02      AdWords  adwords_dsa                31.06        370.0
# 2  2020-01-02      AdWords  adwords_pla             10868.92     191564.0
# 3  2020-01-02      AdWords  adwords_rem               762.06      24668.0
# 4  2020-01-02      AdWords  adwords_sea                41.59        531.0
#
#    clicks  visits  conversions  deliveries  revenue  days
# 0   266.0   306.0          4.0         4.0   5581.0     1
# 1    12.0    11.0          0.0         0.0      NaN     1
# 2  2609.0  2667.0         27.0        27.0  60605.0     1
# 3   386.0   429.0          3.0         3.0   2681.0     1
# 4    26.0    36.0          0.0         0.0      NaN     1

# %%
data = data.drop('createdAt', axis =1)
data = data.groupby(['platformCode', 'channelCode'])['marketingInvestment', 'impressions', 
                                                     'clicks', 'visits', 'deliveries', 'days', 'revenue'].sum()
data = data.reset_index()
# Out:
# <ipython-input-5-54ebdb9e183e>:2: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   data = data.groupby(['platformCode', 'channelCode'])['marketingInvestment', 'impressions',

# %%
data
# Out:
#                   platformCode         channelCode  marketingInvestment  \
# 0                      AdWords         adwords_bra             11016.44
# 1                      AdWords         adwords_dsa              7903.86
# 2                      AdWords         adwords_pla            762545.80
# 3                      AdWords         adwords_rem             66873.70
# 4                      AdWords         adwords_sea              4209.60
# 5                       Adform  adform_prospecting                 0.00
# 6                         Bing                bing                 0.00
# 7   FacebookBusinessAdsManager            facebook              8849.97
# 8                      FirmyCz               zbozi              6684.82
# 9                    HeurekaCz             heureka             10647.19
# 10                 Not tracked              notset                 0.00
# 11                    RtbHouse            rtbhouse            132249.40
# ...
